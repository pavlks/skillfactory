# %%
import requests


response = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
currencies = response.json()

print(currencies)
# Out:
# {'Date': '2021-11-27T11:30:00+03:00', 'PreviousDate': '2021-11-26T11:30:00+03:00', 'PreviousURL': '//www.cbr-xml-daily.ru/archive/2021/11/26/daily_json.js', 'Timestamp': '2021-11-28T16:00:00+03:00', 'Valute': {'AUD': {'ID': 'R01010', 'NumCode': '036', 'CharCode': 'AUD', 'Nominal': 1, 'Name': 'Австралийский доллар', 'Value': 53.803, 'Previous': 53.7123}, 'AZN': {'ID': 'R01020A', 'NumCode': '944', 'CharCode': 'AZN', 'Nominal': 1, 'Name': 'Азербайджанский манат', 'Value': 44.4893, 'Previous': 43.9084}, 'GBP': {'ID': 'R01035', 'NumCode': '826', 'CharCode': 'GBP', 'Nominal': 1, 'Name': 'Фунт стерлингов Соединенного королевства', 'Value': 100.5613, 'Previous': 99.5393}, 'AMD': {'ID': 'R01060', 'NumCode': '051', 'CharCode': 'AMD', 'Nominal': 100, 'Name': 'Армянских драмов', 'Value': 15.6414, 'Previous': 15.4773}, 'BYN': {'ID': 'R01090B', 'NumCode': '933', 'CharCode': 'BYN', 'Nominal': 1, 'Name': 'Белорусский рубль', 'Value': 29.4975, 'Previous': 29.7142}, 'BGN': {'ID': 'R01100', 'NumCode': '975', 'CharCode': 'BGN', 'Nominal': 1, 'Name': 'Болгарский лев', 'Value': 43.5536, 'Previous': 42.7951}, 'BRL': {'ID': 'R01115', 'NumCode': '986', 'CharCode': 'BRL', 'Nominal': 1, 'Name': 'Бразильский реал', 'Value': 13.578, 'Previous': 13.3058}, 'HUF': {'ID': 'R01135', 'NumCode': '348', 'CharCode': 'HUF', 'Nominal': 100, 'Name': 'Венгерских форинтов', 'Value': 23.0836, 'Previous': 22.7812}, 'HKD': {'ID': 'R01200', 'NumCode': '344', 'CharCode': 'HKD', 'Nominal': 10, 'Name': 'Гонконгских долларов', 'Value': 96.9453, 'Previous': 95.6832}, 'DKK': {'ID': 'R01215', 'NumCode': '208', 'CharCode': 'DKK', 'Nominal': 1, 'Name': 'Датская крона', 'Value': 11.4554, 'Previous': 11.2557}, 'USD': {'ID': 'R01235', 'NumCode': '840', 'CharCode': 'USD', 'Nominal': 1, 'Name': 'Доллар США', 'Value': 75.5873, 'Previous': 74.6004}, 'EUR': {'ID': 'R01239', 'NumCode': '978', 'CharCode': 'EUR', 'Nominal': 1, 'Name': 'Евро', 'Value': 84.9526, 'Previous': 83.6793}, 'INR': {'ID': 'R01270', 'NumCode': '356', 'CharCode': 'INR', 'Nominal': 10, 'Name': 'Индийских рупий', 'Value': 10.0941, 'Previous': 10.0088}, 'KZT': {'ID': 'R01335', 'NumCode': '398', 'CharCode': 'KZT', 'Nominal': 100, 'Name': 'Казахстанских тенге', 'Value': 17.3385, 'Previous': 17.2327}, 'CAD': {'ID': 'R01350', 'NumCode': '124', 'CharCode': 'CAD', 'Nominal': 1, 'Name': 'Канадский доллар', 'Value': 59.2609, 'Previous': 58.968}, 'KGS': {'ID': 'R01370', 'NumCode': '417', 'CharCode': 'KGS', 'Nominal': 100, 'Name': 'Киргизских сомов', 'Value': 89.1074, 'Previous': 87.944}, 'CNY': {'ID': 'R01375', 'NumCode': '156', 'CharCode': 'CNY', 'Nominal': 1, 'Name': 'Китайский юань', 'Value': 11.8266, 'Previous': 11.6758}, 'MDL': {'ID': 'R01500', 'NumCode': '498', 'CharCode': 'MDL', 'Nominal': 10, 'Name': 'Молдавских леев', 'Value': 42.5904, 'Previous': 42.0284}, 'NOK': {'ID': 'R01535', 'NumCode': '578', 'CharCode': 'NOK', 'Nominal': 10, 'Name': 'Норвежских крон', 'Value': 83.1553, 'Previous': 83.3152}, 'PLN': {'ID': 'R01565', 'NumCode': '985', 'CharCode': 'PLN', 'Nominal': 1, 'Name': 'Польский злотый', 'Value': 18.1008, 'Previous': 17.9216}, 'RON': {'ID': 'R01585F', 'NumCode': '946', 'CharCode': 'RON', 'Nominal': 1, 'Name': 'Румынский лей', 'Value': 17.2134, 'Previous': 16.9131}, 'XDR': {'ID': 'R01589', 'NumCode': '960', 'CharCode': 'XDR', 'Nominal': 1, 'Name': 'СДР (специальные права заимствования)', 'Value': 105.3611, 'Previous': 103.9855}, 'SGD': {'ID': 'R01625', 'NumCode': '702', 'CharCode': 'SGD', 'Nominal': 1, 'Name': 'Сингапурский доллар', 'Value': 55.0767, 'Previous': 54.5803}, 'TJS': {'ID': 'R01670', 'NumCode': '972', 'CharCode': 'TJS', 'Nominal': 10, 'Name': 'Таджикских сомони', 'Value': 66.9803, 'Previous': 66.1058}, 'TRY': {'ID': 'R01700J', 'NumCode': '949', 'CharCode': 'TRY', 'Nominal': 10, 'Name': 'Турецких лир', 'Value': 62.9333, 'Previous': 62.249}, 'TMT': {'ID': 'R01710A', 'NumCode': '934', 'CharCode': 'TMT', 'Nominal': 1, 'Name': 'Новый туркменский манат', 'Value': 21.6273, 'Previous': 21.3449}, 'UZS': {'ID': ' ...

# %%
def currency_name(cur_id):
    url = 'https://www.cbr-xml-daily.ru/daily_json.js'
    response = requests.get(url)
    currencies = response.json()
    for cur in currencies['Valute']:
        if currencies['Valute'][cur]['ID'] == cur_id:
            return currencies['Valute'][cur]['Name']

# %%
print(currency_name('R01775'))
# Out:
# Швейцарский франк

# %%
from bs4 import BeautifulSoup
import requests

# %%
def wiki_header(url):
    resp = requests.get(url)
    page = BeautifulSoup(resp.text, 'html.parser')
    header = page.find('h1')
    return header.text

# %%
wiki_header('https://en.wikipedia.org/wiki/Operating_system')
# Out:
# 'Operating system'

# %%
def get_actors(url: str) -> list:
    res = requests.get(url)
    code = BeautifulSoup(res.text, 'html.parser')
    spisok = code.find('ul')
    actors_list = [a.text for a in spisok]
    return actors_list

# %%
get_actors('https://www.kinopoisk.ru/film/10079/')
# Out:
# ['Мартин Болсам',
#  'Со Ямамура',
#  'Джейсон Робардс',
#  'Джордж Макреди',
#  'Джеймс Уитмор',
#  'Джозеф Коттен',
#  'Э. Г. Маршалл',
#  'Уэсли Эдди',
#  'Тацуя Михаси',
#  'Такахиро Тамура']

# %%
import pandas as pd

url = 'https://www.cbr.ru/key-indicators/'  
# Таблица с драгметаллами оказалась второй по счёту  
pd.read_html(url)[0]
# Out:
#                         0       1         2          3
# 0               % годовых  1 день       NaN        NaN
# 1  RUONIA  за  25.11.2021     749       NaN        NaN
# 2               % годовых  1 день  2-7 дней  8-30 дней
# 3   MIACR  за  25.11.2021     747       758          —

# %%
from bs4 import BeautifulSoup  
import pandas as pd  
import requests  

url = 'https://www.cbr.ru/key-indicators/'
soup = BeautifulSoup(requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text, 'html.parser')

# %%
all_blocks = soup.find_all('div', class_='key-indicator_content offset-md-2')
# Данные таблицы с драгметаллами находятся во втором блоке
data = all_blocks[1].find('table') 
data
# Out:
# <table>
# <tbody>
# <tr class="denotements">
# <td class="value td-w-13">валюта</td>
# <td class="value td-w-4 _end">26.11.2021</td>
# <td class="value td-w-4 _end">27.11.2021</td>
# </tr>
# <tr>
# <td class="value td-w-13 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Доллар США</div>
# <div class="col-md-3 offset-md-1 _subinfo">USD</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">74,6004</td>
# <td class="value td-w-4 _bold _end mono-num _with-icon _up _red">75,5873</td>
# </tr>
# <tr>
# <td class="value td-w-13 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Евро</div>
# <div class="col-md-3 offset-md-1 _subinfo">EUR</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">83,6793</td>
# <td class="value td-w-4 _bold _end mono-num _with-icon _up _red">84,9526</td>
# </tr>
# </tbody>
# </table>

# %%
df = pd.read_html(str(data))[0]
df
# Out:
#                 0           1           2
# 0          валюта  26.11.2021  27.11.2021
# 1  Доллар США USD      746004      755873
# 2        Евро EUR      836793      849526

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

headers = {
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'en-US,en;q=0.5',
'Connection': 'keep-alive',
'Cookie': 'PHPSESSID=u275tuf1r4tk3abjhof752eih0; aff_sub3=%2Fbanks%2Fratings%2F; BANKI_RU_GUEST_ID=859860658; BANKI_RU_LAST_VISIT=21.11.2021+19%3A13%3A52; BANKI_RU_LAST_ADV=20012_Y; BANKI_RU_USER_IDENTITY_UID=4385664319620088567; BANKI_RU_BANNERS=106_797_1_22112021; ga_client_id=(cid not found); banki_prev_page=%22/banks/ratings/%22',
'Host': 'www.banki.ru',
'Sec-Fetch-Dest': 'document',
'Sec-Fetch-Mode': 'navigate',
'Sec-Fetch-Site': 'none',
'Sec-Fetch-User': '?1',
'Upgrade-Insecure-Requests': '1',
'User-Agent': 'Mozilla/5.0 (X11; Fedora; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0'
}


url = 'https://www.banki.ru/banks/ratings/'
res = requests.get(url, headers=headers)
code = BeautifulSoup(res.text, 'html.parser')
table = code.find('table')
df = pd.read_html(str(table))[0]

# %%
TOKEN = '7b8af8b67b8af8b67b8af8b64d7bf0babc77b8a7b8af8b61a298cfb6b2f09a5b34653ca'
SECRET = '0eoZc0QHnUpIiOzEaNyQ'

# %%
import requests  

url = 'https://api.vk.com/method/users.get'   
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': TOKEN, 'lang': 'ru'}  

# Мы можем выставить параметры запроса через аргумент params  
response = requests.get(url, params=params)  
response.text
# Out:
# '{"response":[{"first_name":"Павел","id":1,"last_name":"Дуров","can_access_closed":true,"is_closed":false,"sex":2,"bdate":"10.10.1984"}]}'

# %%
ids = ",".join(map(str, range(1, 501)))
  
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': TOKEN, 'lang': 'ru'}  
  
res = requests.get(url, params=params).json()
data = pd.DataFrame(res['response'])
data.sex.value_counts()
# Out:
# 2    217
# 1    204
# 0     79
# Name: sex, dtype: int64

# %%
204/(217+204)
# Out:
# 0.4845605700712589

# %%
url = 'https://api.vk.com/method/groups.getMembers'
count = 1000
offset = 0  
user_ids = []
max_count = 100001  
while offset < max_count:  
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))     
    params = {  
        'group_id': 'vk',  
        'v': 5.95,  
        'count': count,  
        'offset': offset,  
        'access_token': TOKEN  
    }     
    # такой же запрос как в прошлый раз  
    r = requests.get(url, params = params)  
    data = r.json()     
    user_ids += data['response']['items']   

    # увеличиваем смещение на количество строк выгрузки  
    offset += count
# Out:
# Выгружаю 1000 пользователей с offset = 0
# Выгружаю 1000 пользователей с offset = 1000
# Выгружаю 1000 пользователей с offset = 2000
# Выгружаю 1000 пользователей с offset = 3000
# Выгружаю 1000 пользователей с offset = 4000
# Выгружаю 1000 пользователей с offset = 5000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 7000
# Выгружаю 1000 пользователей с offset = 8000
# Выгружаю 1000 пользователей с offset = 9000
# Выгружаю 1000 пользователей с offset = 10000
# Выгружаю 1000 пользователей с offset = 11000
# Выгружаю 1000 пользователей с offset = 12000
# Выгружаю 1000 пользователей с offset = 13000
# Выгружаю 1000 пользователей с offset = 14000
# Выгружаю 1000 пользователей с offset = 15000
# Выгружаю 1000 пользователей с offset = 16000
# Выгружаю 1000 пользователей с offset = 17000
# Выгружаю 1000 пользователей с offset = 18000
# Выгружаю 1000 пользователей с offset = 19000
# Выгружаю 1000 пользователей с offset = 20000
# Выгружаю 1000 пользователей с offset = 21000
# Выгружаю 1000 пользователей с offset = 22000
# Выгружаю 1000 пользователей с offset = 23000
# Выгружаю 1000 пользователей с offset = 24000
# Выгружаю 1000 пользователей с offset = 25000
# Выгружаю 1000 пользователей с offset = 26000
# Выгружаю 1000 пользователей с offset = 27000
# Выгружаю 1000 пользователей с offset = 28000
# Выгружаю 1000 пользователей с offset = 29000
# Выгружаю 1000 пользователей с offset = 30000
# Выгружаю 1000 пользователей с offset = 31000
# Выгружаю 1000 пользователей с offset = 32000
# Выгружаю 1000 пользователей с offset = 33000
# Выгружаю 1000 пользователей с offset = 34000
# Выгружаю 1000 пользователей с offset = 35000
# Выгружаю 1000 пользователей с offset = 36000
# Выгружаю 1000 пользователей с offset = 37000
# Выгружаю 1000 пользователей с offset = 38000
# Выгружаю 1000 пользователей с offset = 39000
# Выгружаю 1000 пользователей с offset = 40000
# Выгружаю 1000 пользователей с offset = 41000
# Выгружаю 1000 пользователей с offset = 42000
# Выгружаю 1000 пользователей с offset = 43000
# Выгружаю 1000 пользователей с offset = 44000
# Выгружаю 1000 пользователей с offset = 45000
# Выгружаю 1000 пользователей с offset = 46000
# Выгружаю 1000 пользователей с offset = 47000
# Выгружаю 1000 пользователей с offset = 48000
# Выгружаю 1000 пользователей с offset = 49000
# Выгружаю 1000 пользователей с offset = 50000
# Выгружаю 1000 пользователей с offset = 51000
# Выгружаю 1000 пользователей с offset = 52000
# Выгружаю 1000 пользователей с offset = 53000
# Выгружаю 1000 пользователей с offset = 54000
# Выгружаю 1000 пользователей с offset = 55000
# Выгружаю 1000 пользователей с offset = 56000
# Выгружаю 1000 пользователей с offset = 57000
# Выгружаю 1000 пользователей с offset = 58000
# Выгружаю 1000 пользователей с offset = 59000
# Выгружаю 1000 пользователей с offset = 60000
# Выгружаю 1000 пользователей с offset = 61000
# Выгружаю 1000 пользователей с offset = 62000
# Выгружаю 1000 пользователей с offset = 63000
# Выгружаю 1000 пользователей с offset = 64000
# Выгружаю 1000 пользователей с offset = 65000
# Выгружаю 1000 пользователей с offset = 66000
# Выгружаю 1000 пользователей с offset = 67000
# Выгружаю 1000 пользователей с offset = 68000
# Выгружаю 1000 пользователей с offset = 69000
# Выгружаю 1000 пользователей с offset = 70000
# Выгружаю 1000 пользователей с offset = 71000
# Выгружаю 1000 пользователей с offset = 72000
# Выгружаю 1000 пользователей с offset = 73000
# Выгружаю 1000 пользователей с offset = 74000
# Выгружаю 1000 пользователей с offset = 75000
# Выгружаю 1000 пользователей с offset = 76000
# Выгружаю 1000 пользователей с offset = 77000
# Выгружаю 1000 пользователей с offset = 78000
# Выгружаю 1000 пользователей с offset = 79000
# Выгружаю 1000 пользователей с offset = 80000
# Выгружаю 1000 пользователей с offset = 81000
# Выгружаю 1000 пользователей с offset = 82000
# Выгружаю 1000 пользователей с offset = 83000
# Выгружаю 1000 пользователей с offset = 84000
# Выгружаю 1000 пользователей с offset = 85000
# Выгружаю 1000 пользователей с offset = 86000
# Выгружаю 1000 пользователей с offset = 87000
# Выгружаю 1000 пользователей с offset = 88000
# Выгружаю 1000 пользователей с offset = 89000
# Выгружаю 1000 пользователей с offset = 90000
# Выгружаю 1000 пользователей с offset = 91000
# Выгружаю 1000 пользователей с offset = 92000
# Выгружаю 1000 пользователей с offset = 93000
# Выгружаю 1000 пользователей с offset = 94000
# Выгружаю 1000 пользователей с offset = 95000
# Выгружаю 1000 пользователей с offset = 96000
# Выгружаю 1000 пользователей с offset = 97000
# Выгружаю 1000 пользователей с offset = 98000
# Выгружаю 1000 пользователей с offset = 99000
# Выгружаю 1000 пользователей с offset = 100000

# %%
len(user_ids)
# Out:
# 101000

# %%
user_ids[99999]
# Out:
# 6078488

# %%
import requests  
from pprint import pprint  
  
url = 'https://api.vk.com/method/wall.get'  
params = {  
    'domain': 'vk',  
    'filter': 'owner',  
    'count': 10,  
    'offset': 0,  
    'access_token': TOKEN,  
    'v': 5.95  
}  
response = requests.get(url, params = params)  
response.json()
# Out:
# {'response': {'count': 445,
#   'items': [{'id': 1229241,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1634026934,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'ВКонтакте становится больше\n\nТеперь бренд VK объединяет ещё больше сервисов: [club39554210|Почту], [club137839839|Юлу], [club17700656|Delivery Club], [club66669811|Skillbox], [club90274300|Ситимобил], [club182144558|Самокат] и другие. Проекты будут обмениваться самыми удачными решениями — а значит, вы сможете ещё раньше пробовать новые возможности.\n\nПрочитайте больше об [https://vk.com/ecosystem|экосистеме VK] 👈 По ссылке — подарок: подписка VK Combo за 75 рублей в месяц. Правила акции: vk.cc/c6Rsim',
#     'is_pinned': 1,
#     'attachments': [{'type': 'video',
#       'video': {'access_key': '109c7876043aa21574',
#        'can_comment': 0,
#        'can_like': 1,
#        'can_repost': 1,
#        'can_subscribe': 1,
#        'can_add_to_faves': 1,
#        'can_add': 1,
#        'comments': 94,
#        'date': 1634027241,
#        'description': 'ВКонтакте становится больше: сервисы, платежи, VK Combo',
#        'duration': 12,
#        'photo_130': 'https://sun6-23.userapi.com/impf/WmFqWlTb94_gIZLJXRrk9q6iFOMqHzWdXV3Eug/cWXmcW9Ns-w.jpg?size=130x96&quality=96&keep_aspect_ratio=1&background=000000&sign=f7af05c9a0bfa1185cfadf305839c49d&c_uniq_tag=jCM4yy-QXXdeznT1IAqp5zi5Qh-NxWZ_mx3g06GqZHw&type=video_thumb',
#        'photo_320': 'https://sun6-23.userapi.com/impf/WmFqWlTb94_gIZLJXRrk9q6iFOMqHzWdXV3Eug/cWXmcW9Ns-w.jpg?size=320x240&quality=96&keep_aspect_ratio=1&background=000000&sign=aa25827598b22ed7ef9ab6b623df693b&c_uniq_tag=tqn_KwVTRRPl4ACiJSZ1aCmnq16MD1i6KYj5c3Kpg6c&type=video_thumb',
#        'photo_800': 'https://sun6-23.userapi.com/impf/WmFqWlTb94_gIZLJXRrk9q6iFOMqHzWdXV3Eug/cWXmcW9Ns-w.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=a1fbd7b4e60567b6f42fee1c341fb176&c_uniq_tag=CEDSCNvFadVoa5ZclM4FLEqkYmher8ekCmcS5PPpp80&type=video_thumb',
#        'photo_1280': 'https://sun6-23.userapi.com/impf/WmFqWlTb94_gIZLJXRrk9q6iFOMqHzWdXV3Eug/cWXmcW9Ns-w.jpg?size=1280x721&quality=96&sign=6d2576bae409edd8ff7cceeaccc46521&c_uniq_tag=9AUIYv2xBO60mNqUB7F22KZSIH1XrYt97d-tarH0oyE&type=video_thumb',
#        'first_frame_130': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=130x73&quality=96&sign=ba285b2f49ecf686ff094ce6ec76466d&c_uniq_tag=4Dpb8Hm_KOfhmq_YU0CHx7_BGC0gz1RE0VRhNV8PTdk&type=video_first_frame',
#        'first_frame_160': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=160x90&quality=96&sign=4bb20311ea8c2960b3da70099bdcd124&c_uniq_tag=GipWZQ1lNMVF0nOdI9A4ptOZcixJkO5KvN1a5Rqtu4k&type=video_first_frame',
#        'first_frame_320': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=320x180&quality=96&sign=bb5b01b40fb8d15b221b81237f5882bd&c_uniq_tag=u_4BfFJbk14xMh5gJ7-3ec7Bw175QobEUPP1_eu_fDc&type=video_first_frame',
#        'first_frame_800': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=800x451&quality=96&sign=a42245e43d3cf6a743c6362dfff23b80&c_uniq_tag=7KxmmTNSMLxsuvOf9l8is8GvfJKdihbT1tjvsOugTY8&type=video_first_frame',
#        'first_frame_1280': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=1280x721&quality=96&sign=9591cd4916a1c6030587ea6ee35ca36f&c_uniq_tag=_6JHgNvxXpiQ7WpZfV20j92L0p0FOcj067JX3CJeP_k&type=video_first_frame',
#        'width': 1278,
#        'height': 720,
#        'id': 456241031,
#        'owner_id': -22822305,
#        'title': 'Экосистема VK – встречайте!',
#        'track_code': 'video_9f5735c2fUNXbDxQarW_FFyxndmEJlt53PzSvqYoQsPWawGD47NNYkluOzdptb4dW9qY7LIUb0jsz-O60Ukur9Y',
#        'repeat': 1,
#        'views': 82279018}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 6491, 'groups_can_post': True},
#     'likes': {'can_like': 1,
#      'count': 63349,
#      'user_likes': 0,
#      'can_publish': 1},
#     'reposts': {'count': 11092, 'user_reposted': 0},
#     'views': {'count': 92718620},
#     'edited': 1634031226,
#     'hash': 'rnZ3XxEv_Sz20Kz1CQ'},
#    {'id': 1248068,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1637941192,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Эксклюзивное шоу, мультфильмы для непосед или новый сериал? Собирайте плейлист на выходные уже сегодня: всё, что вы хотите посмотреть, легко найдётся на новой [https://vk.com/video|видеовитрине VK Видео]! \n\nЗаходите в «Видео» в версии ВКонтакте для компьютера или на вкладке «Сервисы» в мобильном приложении. И ныряйте в огромную библиотеку: фильмы, сериалы, телешоу, матчи, киберспортивные трансляции и ещё миллионы роликов других жанров — выбирай
],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 1436, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 2171, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 525, 'user_reposted': 0},
#     'views': {'count': 933067},
#     'edited': 1634483355,
#     'hash': 'to3kLKRLP9_NrHMNvA'},
#    {'id': 1235268,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1634311497,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Встречайте VK Видео — крупнейший видеосервис в России! Он объединил на новой видеовитрине ролики и трансляции из ВКонтакте, Одноклассников и других платформ. Смотрите сами: vk.com/video.\n\nТеперь вас ждёт ещё больше оригинального контента, любимых фильмов, шоу и сериалов — бесплатно и в качестве 4К. Продвинутые технологии единой видеоплатформы обеспечивают комфортный просмотр: например, ролики стартуют максимально быстро, нестабильная связь почти не влияет на воспроизведение, а кросс-платформенный плеер позволяет включать видео на телефоне, ноутбуке или планшете. \n\nНайти всё самое интересное помогут технологии искусственного интеллекта. Они определяют тематику и действующих лиц в роликах, поэтому на вашей видеовитрине разместятся видео от друзей, любимых знаменитостей и другой актуальный для вас контент. Скоро в VK Видео появятся ещё и панорамные видео 360° — смотреть их, как и другие ролики, можно будет на больших экранах с помощью приложения для Smart TV.',
#     'attachments': [{'type': 'video',
#       'video': {'access_key': '1c22a81a8940ed3160',
#        'can_comment': 0,
#        'can_like': 1,
#        'can_repost': 1,
#        'can_subscribe': 1,
#        'can_add_to_faves': 1,
#        'can_add': 1,
#        'comments': 12,
#        'date': 1634305969,
#        'description': 'Ещё больше оригинального контента, любимых фильмов, шоу и сериалов бесплатно и в высоком качестве теперь ВКонтакте.',
#        'duration': 20,
#        'photo_130': 'https://i.mycdn.me/getVideoPreview?id=1631217388225&idx=14&type=39&tkn=8ii5gBlQ_NEKAs_c314QPKM577I&fn=vid_s',
#        'photo_320': 'https://i.mycdn.me/getVideoPreview?id=1631217388225&idx=14&type=39&tkn=8ii5gBlQ_NEKAs_c314QPKM577I&fn=vid_l',
#        'photo_800': 'https://i.mycdn.me/getVideoPreview?id=1631217388225&idx=14&type=39&tkn=8ii5gBlQ_NEKAs_c314QPKM577I&fn=vid_x',
#        'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=1631217388225&idx=14&type=39&tkn=8ii5gBlQ_NEKAs_c314QPKM577I&fn=vid_w',
#        'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=1631217388225&idx=0&type=35&tkn=E_D-5KQZkAj9Uk98p9zHCCd_6B4',
#        'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=1631217388225&idx=0&type=34&tkn=rnBXmy2OrVpA_b7TH4xwaVxRJmI',
#        'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=1631217388225&idx=0&type=33&tkn=ZDXhwiEz9MAbbtUN1pFjk_6pp8w',
#        'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=1631217388225&idx=0&type=32&tkn=kj3F4Gsatpm9mYhnKbGdmVXSGHw',
#        'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=1631217388225&idx=0&type=39&tkn=BR66TK_9uF6teB6mY6gfEPJTbwg',
#        'width': 1920,
#        'height': 1080,
#        'id': 456241052,
#        'owner_id': -22822305,
#        'title': 'Встречайте VK Видео',
#        'track_code': 'video_caef3b0cXvs_0slwPb2LMfu29UxD3ce0AJucyLa5oESfbKLUp-Vu2iHQzhc-vYs0_N_5eXXv84Uwrq7MwdjMKJ8',
#        'views': 576191}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 649, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 1694, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 671, 'user_reposted': 0},
#     'views': {'count': 709647},
#     'hash': 'zKaaTKkaO3nvqGKlhA'},
#    {'id': 1224655,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1633878003,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Как и обещали, в наш день рождения представляем первых [https://vk.com/@vk-pobediteli|обладателей суперпризов] 🎁 В течение ближайших 24 часов пришлём победителям сообщение от сообщества ВКонтакте с инструкцией, как получить выигрыш. Поздравляем! \n\nА если сегодня приз вам не выпал — айда снова на [https://vk.com/app7550574#party|«Вечеринку»]! Праздник продолжается: играйте, и 17 октября есть шанс обнаружить себя среди счастливчиков. Чем больше попыток, тем ближе суперпризы: MacBook Pro, новенькие смартфоны и другие классные гаджеты или подписки на VK Combo на 15 лет.',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 
рацией в 4К и без лимитов по времени, запустили музыкальный кабинет для авторов и прокачали донаты, добавили в мессенджер целый ряд новых возможностей, эффектно вернулись на iPad. \n\nВместе с ВКонтакте люди влюбляются, учатся новому, отдыхают, поддерживают связь с самыми близкими, творят и становятся знаменитыми, ведут бизнес, а иногда — грустят или по кому-то скучают. Каждый день у нас более 1 млрд просмотров видео, 15 млрд сообщений и 9 млрд просмотров постов.\nВсё это возможно благодаря Команде ВКонтакте — это увлечённые, творческие и талантливые люди. Горжусь! \n\nУже 15 лет бьём рекорды и не собираемся на этом останавливаться!\n\nС праздником! 💫🎉',
#       'attachments': [{'type': 'photo',
#         'photo': {'album_id': -7,
#          'date': 1633862152,
#          'id': 457240038,
#          'owner_id': 92933,
#          'has_tags': False,
#          'access_key': '55afa5a3d775a2bda4',
#          'sizes': [{'height': 130,
#            'url': 'https://sun6-23.userapi.com/impg/WLL2pwH0ndaBMULPFdA6A6qcaJWuzg7x7kV0Og/Sf9uWjmabpM.jpg?size=130x130&quality=96&sign=14cdc40837c2696a186ead95779bffa3&c_uniq_tag=re47_rzq-lfGtAtWF2jVyLr_etBxOlrVMbEM-7_oKOI&type=album',
#            'type': 'm',
#            'width': 130},
#           {'height': 130,
#            'url': 'https://sun6-23.userapi.com/impg/WLL2pwH0ndaBMULPFdA6A6qcaJWuzg7x7kV0Og/Sf9uWjmabpM.jpg?size=130x130&quality=96&sign=14cdc40837c2696a186ead95779bffa3&c_uniq_tag=re47_rzq-lfGtAtWF2jVyLr_etBxOlrVMbEM-7_oKOI&type=album',
#            'type': 'o',
#            'width': 130},
#           {'height': 200,
#            'url': 'https://sun6-23.userapi.com/impg/WLL2pwH0ndaBMULPFdA6A6qcaJWuzg7x7kV0Og/Sf9uWjmabpM.jpg?size=200x200&quality=96&sign=fed615b29df45621e539af73439c5a34&c_uniq_tag=lGSxCYXTIBbN2lcTDNN6_mfDolePp5ByzD7SHvo0jVU&type=album',
#            'type': 'p',
#            'width': 200},
#           {'height': 320,
#            'url': 'https://sun6-23.userapi.com/impg/WLL2pwH0ndaBMULPFdA6A6qcaJWuzg7x7kV0Og/Sf9uWjmabpM.jpg?size=320x320&quality=96&sign=82280b5058a36b37c167629474f42888&c_uniq_tag=DsM98AKbjWJj7FCtKgj89Y9756fBnknq-Eafz41eNWg&type=album',
#            'type': 'q',
#            'width': 320},
#           {'height': 510,
#            'url': 'https://sun6-23.userapi.com/impg/WLL2pwH0ndaBMULPFdA6A6qcaJWuzg7x7kV0Og/Sf9uWjmabpM.jpg?size=510x510&quality=96&sign=2d56639395832d606e1819709b74d8a1&c_uniq_tag=jIcMKveqd1_DRWWk_pBchmZ1Qj4lwBKGUT9SEvfMcQk&type=album',
#            'type': 'r',
#            'width': 510},
#           {'height': 75,
#            'url': 'https://sun6-23.userapi.com/impg/WLL2pwH0ndaBMULPFdA6A6qcaJWuzg7x7kV0Og/Sf9uWjmabpM.jpg?size=75x75&quality=96&sign=3f112f6156879d96f3bd33bc484181bc&c_uniq_tag=4W_39ruqwPjdAwq-JFe8SFfyHP-YfhAegahWZNyV2EQ&type=album',
#            'type': 's',
#            'width': 75},
#           {'height': 604,
#            'url': 'https://sun6-23.userapi.com/impg/WLL2pwH0ndaBMULPFdA6A6qcaJWuzg7x7kV0Og/Sf9uWjmabpM.jpg?size=604x604&quality=96&sign=8647808e21d28700ed920423a16f303b&c_uniq_tag=EFXsmwA7slIlytU1Ipx9orr_JbpDbxQXS7ysGif-xXY&type=album',
#            'type': 'x',
#            'width': 604},
#           {'height': 807,
#            'url': 'https://sun6-23.userapi.com/impg/WLL2pwH0ndaBMULPFdA6A6qcaJWuzg7x7kV0Og/Sf9uWjmabpM.jpg?size=807x807&quality=96&sign=7a794f8528c7f8b916cd4dc7193d9c39&c_uniq_tag=sbsLibaXRow75N9XS_MaqODvP3cw0NNuE5UjrlRw4K4&type=album',
#            'type': 'y',
#            'width': 807},
#           {'height': 1080,
#            'url': 'https://sun6-23.userapi.com/impg/WLL2pwH0ndaBMULPFdA6A6qcaJWuzg7x7kV0Og/Sf9uWjmabpM.jpg?size=1080x1080&quality=96&sign=6ce00819ab7133f16ed10751146ee4d0&c_uniq_tag=K4HVxgbIGzmszwCbRtG3XLFxPBlEv-mrK3_XhA0Z1vU&type=album',
#            'type': 'z',
#            'width': 1080}],
#          'text': ''}}],
#       'post_source': {'type': 'vk'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count':
#      {'type': 'doc',
#       'doc': {'id': 612429107,
#        'owner_id': 50308459,
#        'title': 'Pravila_aktsii_Naydi_pinyaty.pdf',
#        'size': 119838,
#        'ext': 'pdf',
#        'date': 1633722013,
#        'type': 1,
#        'url': 'https://vk.com/doc50308459_612429107?hash=a97e9b375be3105ec8&dl=GA:1638111497:4c06c2f5d53a23731a&api=1&no_preview=1',
#        'access_key': 'ec62ee91ef42a9eb97'}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 4208, 'groups_can_post': True},
#     'likes': {'can_like': 1,
#      'count': 22225,
#      'user_likes': 0,
#      'can_publish': 1},
#     'reposts': {'count': 7598, 'user_reposted': 0},
#     'views': {'count': 7875940},
#     'edited': 1633768637,
#     'hash': 'hosB866I9v3HQCPtkw'},
#    {'id': 1217402,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1633374911,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 386,
#       'owner_id': 92933,
#       'from_id': 92933,
#       'date': 1633374659,
#       'post_type': 'post',
#       'text': 'Наша техническая команда оптимизирует работу оборудования для стабильной работы сервисов в связи со скачком активности. На 18% выросло количество просмотров видео ВКонтакте, на 21% — число отправленных сообщений в мессенджере. За сегодняшний вечер вырос и объём активной аудитории ВКонтакте — на 19% по сравнению с вчерашними показателями. Прикладываем все усилия, чтобы ваше общение не прерывалось.',
#       'post_source': {'type': 'vk'}}],
#     'post_source': {'platform': 'iphone', 'type': 'api'},
#     'comments': {'can_post': 1, 'count': 810, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 3542, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 1940, 'user_reposted': 0},
#     'views': {'count': 966196},
#     'hash': 'Y9lo0ZB_uETRLROSlA'},
#    {'id': 1196136,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1633093959,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '10 октября ВКонтакте исполнится 15 лет — и мы, конечно, не представляем этот праздник без вас. Приглашаем на [https://vk.com/app7550574#party|«Вечеринку»] в мини-приложение «VK Чекбэк» — подарок ждёт каждого! \n\nЗаходите, располагайтесь и… крутите стол! Проигравших не будет: за каждый ход вам достанется подарок от наших партнёров. Чем чаще испытываете удачу — тем выше шанс получить один из суперпризов: MacBook Pro, смартфоны iPhone 12 и Samsung Galaxy S21, электросамокат Xiaomi, AirPods Pro, Apple Watch, умную колонку Капсулу с голосовым помощником Марусей, подписку VK Combo на 15 лет или камеру GoPro Hero 9. Кроме того, на «Вечеринке» мы разыграем 15 миллионов бонусных рублей VK Pay. \n\nНа старте у вас есть одна попытка, ещё одна появится через 2 дня. Чтобы получить больше ходов, можно выполнять задания: например, заказать блюдо в Еде ВКонтакте, пройти 10\u202f000 шагов или завести ящик в VK Почте. \n\nСписки счастливчиков, которые уйдут с «Вечеринки» с суперпризами, опубликуем в этом сообществе 10 и 17 октября. Да, будет два больших розыгрыша! А билеты на концерты и в музеи, мерч топовых артистов, скидки на образовательные курсы и заказы в Еде ВКонтакте, а также многое другое можно получить сразу — как только вам выпадет такой приз. Удачи 😉',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1632999575,
#        'id': 457322473,
#        'owner_id': -22822305,
#        'has_tags': False,
#        'access_key': '1ed5fcf8e4978526d8',
#        'post_id': 1196136,
#        'sizes': [{'height': 114,
#          'url': 'https://sun6-22.userapi.com/impg/3C7Cl63fXDyNIlBlpFcqgt0F8dTWdbVGVqanlQ/0rRWQQsA6c0.jpg?size=130x114&quality=96&sign=b01cde9ec1409450b4ae291bbc9922a4&c_uniq_tag=XgPIWE1xgev3Vjd0enDaeAnLtnFWvyAAiJGkly-hyMQ&type=album',
#          'type': 'm',
#          'width': 130},
#         {'height': 114,
#          'url': 'https://sun6-22.userapi.com/impg/3C7Cl63fXDyNIlBlpFcqgt0F8dTWdbVGVqanlQ/0rRWQQsA6c0.jpg?size=130x114&quality=96&sign=b01cde9ec1409450b4ae291bbc9922a4&c_uniq_tag=XgPIWE1xgev3Vjd0enDaeAnLtnFWvyAAiJGkly-hyMQ&type=album',
#          'type': 'o',
#          'width': 130},
#         {'height': 176,
#          'url': 'https://sun6-22.userapi.com/impg/3C7Cl63fXDyNIlBlpFcqgt0F8dTWdbVGVqanlQ/0rRWQQsA6c0.jpg?size=200x176&quality=96&sign=b47f0a17d6ffd37d218a03ca80a54e00&c_uniq_tag=PqcZNinuR9NxeQceFxldJde3FogocTpRY2MhG1kwQMA&type=album',
#          'type': 'p',
#          'width': 200},
#         {'height': 281,
#          'url': 'https://sun6-22.userapi.com/impg/3C7Cl63fXDyNIlBlpFcqgt0F8dTWdbVGVqanlQ/0rRWQQsA6c0.jpg?size=320x281&quality=96&sign=ff13a65df88a90b7801a9333e2975df7&c_uniq_tag=UzxhQqnnxdEECL2BICoxLxMDuLkOiCcvRCe2KQ1JBeE&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 448,
#          'url': 'https://sun6-22.userapi.com/impg/3C7Cl63fXDyNIlBlpFcqgt0F8dTWdbVGVqanlQ/0rRWQQsA6c0.jpg?size=510x448&quality=96&sign=ad03b553a30c315baee4c77b4f45227b&c_uniq_tag=oj8QDUdujXigcOoXHQEuY7Y0s1JHRhp2lZG1F6Bm5bc&type=album',
#          'type': 'r',
#          'width': 510},
#         {'height': 66,
#          'url': 'https://sun6-22.userapi.com/impg/3C7Cl63fXDyNIlBlpFcqgt0F8dTWdbVGVqanlQ/0rRWQQsA6c0.jpg?size=75x66&quality=96&sign=fb58925ccc3d85aa9a2ed1dab2d0f010&c_uniq_tag=PLE3XtqU3vxFlvQl7Is_yHQfZZQ6xVvVddXpRfqO9ok&type=album',
#          'type': 's',
#          'width': 75},
#         {'height': 1757,
#          'url': 'https://sun6-22.userapi.com/impg/3C7Cl63fXDyNIlBlpFcqgt0F8dTWdbVGVqanlQ/0rRWQQsA6c0.jpg?size=2000x1757&quality=96&sign=87ea8c8da974afd2298a05af31ef31e8&c_uniq_tag=4geKFU3TSggcX6l2vBFPvUZbsyhNBhi1fjRKMgk6jFk&type=album',
#          'type': 'w',
#          'width': 2000},
#         {'height': 531,
#          'url': 'https://sun6-22.userapi.com/impg/3C7Cl63fXDyNIlBlpFcqgt0F8dTWdbVGVqanlQ/0rRWQQsA6c0.jpg?size=604x531&quality=96&sign=0f4b0d801c7ee265574c1a51368b2433&c_uniq_tag=O6HN2OKnODkYS0FD94Y-ydzBZN3hCmmfmpikYL-MhV4&type=album',
#          'type': 'x',
#          'width': 604},
#         {'height': 709,
#          'url': 'https://sun6-22.userapi.com/impg/3C7Cl63fXDyNIlBlpFcqgt0F8dTWdbVGVqanlQ/0rRWQQsA6c0.jpg?size=807x709&quality=96&sign=b213169c794b18c9b856f7aefc073bbb&c_uniq_tag=Ji35yCQWn417-37SPHx54l6VfR5Hrdb03RCPH1NhdT8&type=album',
#          'type': 'y',
#          'width': 807},
#         {'height': 1080,
#          'url': 'https://sun6-22.userapi.com/impg/3C7Cl63fXDyNIlBlpFcqgt0F8dTWdbVGVqanlQ/0rRWQQsA6c0.jpg?size=1280x1124&quality=96&sign=52ada339100b3e94e8b1102acae7c18e&c_uniq_tag=w4-Lzju9NipE4DTbcYX0Ugptov2rVmk3VuHGP_L3GSE&type=album',
#          'type': 'z',
#          'width': 1229}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 1326, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 3599, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 2986, 'user_reposted': 0},
#     'views': {'count': 770445},
#     'hash': 'J3lTBcBN1o1ghZmTGQ'}]}}

# %%
stats = {}  
              
for record in response.json()['response']['items'][:]:  
    title = record['text'][:30]  
    if title:  
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date'] ]  
pprint(stats)
# Out:
# {'10 октября ВКонтакте исполнитс': [1326, 3599, 2986, 1633093959],
#  'ВКонтакте становится больше\n\nТ': [6491, 63349, 11092, 1634026934],
#  'Встречайте VK Видео — крупнейш': [649, 1694, 671, 1634311497],
#  'За столом на нашей «Вечеринке»': [1436, 2171, 525, 1634482803],
#  'Как и обещали, в наш день рожд': [4307, 4360, 1058, 1633878003],
#  'Какой праздник без игр и весел': [4208, 22225, 7598, 1633724266],
#  'Приложение теперь подстраивает': [2326, 10627, 7187, 1635347061],
#  'Эксклюзивное шоу, мультфильмы ': [158, 576, 76, 1637941192]}

# %%
token = TOKEN
get_smm_index('vk', token)
# => 0.00337003
get_smm_index(group_name, token),

def get_smm_index(group_name, token):
    url = 'https://api.vk.com/method/wall.get'  
    params = {
        'domain': 'vk',
        'filter': 'owner',
        'count': 10,
        'offset': 0,
        'access_token': TOKEN,
        'v': 5.95
    }
    response = requests.get(url, params = params)
    r = response.json()
    for record in r['response']['items'][:]:  
        title = record['text'][:30]  
        if title:  
            stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date'] ]
