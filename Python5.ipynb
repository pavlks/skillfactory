# %%
import pandas as pd

df = pd.read_csv('data_sf.xls')
df.head()
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df.describe(include='all'))
# Out:
#           Unnamed: 0          Name           Age Nationality             Club  \
# count   12897.000000         12897  12897.000000       12897            12897
# unique           NaN         12326           NaN         156              650
# top              NaN  J. Rodríguez           NaN     England  Shonan Bellmare
# freq             NaN             9           NaN        1368               30
# mean     6605.040862           NaN     24.795379         NaN              NaN
# std      3782.545526           NaN      4.872212         NaN              NaN
# min         0.000000           NaN     16.000000         NaN              NaN
# 25%      3357.000000           NaN     21.000000         NaN              NaN
# 50%      6622.000000           NaN     24.000000         NaN              NaN
# 75%      9876.000000           NaN     28.000000         NaN              NaN
# max     13125.000000           NaN     45.000000         NaN              NaN
#
# ...

# %%
print(
    df['Age'].mean(),
    df.Composure.count(),
    df['ShortPassing'].std(),
    df.Wage.sum(),
    df['Value'].min(),
    sep='\n'
)
# Out:
# 24.795378770256647
# 12897
# 14.740435689517149
# 96954000
# 0

# %%
df[df.Age > 20]
df[(df['Age'] > df.Age.mean()) & (df.Club == 'Juventus')]
df[(df['Age'] > 20) & (df.Club == 'FC Barcelona')].Wage.mean()
# Out:
# 227647.0588235294

# %% [markdown]
# # Задания

# %%
df[df.Wage > df.Wage.mean()].SprintSpeed.mean()
# Out:
# 67.56638061585058

# %%
df[df.Wage < df.Wage.mean()].SprintSpeed.mean()
df[df['Wage'] < df['Wage'].mean()]['SprintSpeed'].mean()
# Out:
# 62.41425430560645

# %%
df[df['Wage'] == df.Wage.max()][['Name', 'Position']]
# Out:
#        Name Position
# 0  L. Messi       RF

# %%
df[df['Nationality'] == 'Brazil'].Penalties.sum()
# Out:
# 22789

# %%
df[df.HeadingAccuracy > 50]['Age'].mean()
# Out:
# 25.58771113179944

# %%
df[(df.Composure > 0.9 * df.Composure.max()) & (df.Reactions > 0.9 * df.Reactions.max())][['Name', 'Age']].min()
# Out:
# Name    A. Griezmann
# Age               24
# dtype: object

# %%
old_react = df[df['Age'] == df['Age'].max()]['Reactions'].mean()
young_react = df[df['Age'] == df['Age'].min()]['Reactions'].mean()
old_react - young_react
# Out:
# 22.642857142857146

# %%
df[df.Value > df.Value.mean()].describe(include='all')
# Out:
#           Unnamed: 0          Name         Age Nationality               Club  \
# count    1747.000000          1747  1747.00000        1747               1747
# unique           NaN          1558         NaN          98                447
# top              NaN  J. Rodríguez         NaN       Spain  FC Bayern München
# freq             NaN             9         NaN         211                 17
# mean     1838.520893           NaN    26.02862         NaN                NaN
# std      2709.547727           NaN     3.89970         NaN                NaN
# min         0.000000           NaN    16.00000         NaN                NaN
# 25%       442.500000           NaN    23.00000         NaN                NaN
# 50%       893.000000           NaN    26.00000         NaN                NaN
# 75%      1392.000000           NaN    29.00000         NaN                NaN
# max     13098.000000           NaN    40.00000         NaN                NaN
#
# ...

# %%
wage_gk_ref = df[df['GKReflexes'] == df['GKReflexes'].max()].Wage.mean()
wage_gk_han = df[df['GKHandling'] == df['GKHandling'].max()].Wage.mean()
wage_gk_ref / wage_gk_han
# Out:
# 2.765957446808511

# %%
amax_shot = df[df['Aggression'] == df.Aggression.max()].ShotPower.mean()
amin_shot = df[df['Aggression'] == df['Aggression'].min()]['ShotPower'].mean()
amax_shot / amin_shot
# Out:
# 2.076923076923077
